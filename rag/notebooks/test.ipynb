# %%
import datetime

# %%
print(datetime.datetime.now())
# Out:
# 2026-07-02 08:06:23.911634

# %% [markdown]
# **This is bold**

# %% [markdown]
# ### Use methods of date

# %%
name = input("Enter your name :")

# %%
print(name)
# Out:
# dfasdfsdfdsfsd

# %%
if name == 'end':
        print('The End')
else:
  print("Name = ", name)
# Out:
# Name =  fsdfsdf

# %%
print('Over')
# Out:
# Over
